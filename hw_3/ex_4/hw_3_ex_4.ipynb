# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
# !nvidia-smi
# Out:
# Fri Dec 16 22:12:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Preparations

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Colab Notebooks/AppliedGPU_hw3/ex_4'
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/AppliedGPU_hw3/ex_4
# bin  include  inputfiles  Makefile  src

# %% [markdown]
# # Compiling

# %%
# !make clean
# Out:
# rm -rf  src/TransArraySpace3D.o src/EMfield.o src/InterpDensSpecies.o src/Grid.o src/ConfigFile.o src/RW_IO.o src/Particles.o src/InterpDensNet.o src/EMfield_aux.o src/sputniPIC.o src/Basic.o src/Particles_aux.o src/BC.o src/Timing.o
# rm -rf sputniPIC.out

# %%
# !make all
# Out:
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -G -Xcompiler -Wall src/TransArraySpace3D.cpp -c -o src/TransArraySpace3D.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -G -Xcompiler -Wall src/EMfield.cpp -c -o src/EMfield.o

# %% [markdown]
# # Execution and Profiling

# %%
# !./bin/sputniPIC.out inputfiles/GEM_2D.inp
